# %%
import pandas as pd

# %%
import pandas as pd

def convert_clinvar_txt_to_csv(input_file, output_file):
    """
    Convert ClinVar FBN1 data from tab-delimited text to CSV format
    
    Args:
        input_file (str): Path to input text file
        output_file (str): Path to output CSV file
    """
    
    # Read the tab-delimited file
    df = pd.read_csv(input_file, sep='\t', low_memory=False)
    
    # Display basic info about the data
    print(f"Original data shape: {df.shape}")
    print(f"Columns: {list(df.columns)}")
    print(f"First few rows:")
    print(df.head())
    
    # Save as CSV
    df.to_csv(output_file, index=False)
    
    print(f"\nConversion complete!")
    print(f"Input file: {input_file}")
    print(f"Output file: {output_file}")
    print(f"Rows converted: {len(df)}")

def analyze_clinvar_data(csv_file):
    """
    Perform basic analysis on the converted ClinVar data
    """
    df = pd.read_csv(csv_file)
    
    print("\n=== Data Analysis ===")
    print(f"Total variants: {len(df)}")
    
    # Count by classification
    classification_counts = df['Germline classification'].value_counts()
    print("\nGermline classification counts:")
    for classification, count in classification_counts.items():
        print(f"  {classification}: {count}")
    
    # Count by variant type
    variant_type_counts = df['Variant type'].value_counts()
    print("\nVariant type counts:")
    for variant_type, count in variant_type_counts.items():
        print(f"  {variant_type}: {count}")
    
    # Count by molecular consequence
    consequence_counts = df['Molecular consequence'].value_counts()
    print("\nMolecular consequence counts:")
    for consequence, count in consequence_counts.items():
        print(f"  {consequence}: {count}")

if __name__ == "__main__":
    # File paths
    input_txt_file = "clinvar_fbn1.txt"
    output_csv_file = "clinvar_fbn1.csv"
    
    # Convert the file
    convert_clinvar_txt_to_csv(input_txt_file, output_csv_file)
    
    # Analyze the data
    analyze_clinvar_data(output_csv_file)
# Out:
# Original data shape: (4319, 25)
# Columns: ['Name', 'Gene(s)', 'Protein change', 'Condition(s)', 'Accession', 'GRCh37Chromosome', 'GRCh37Location', 'GRCh38Chromosome', 'GRCh38Location', 'VariationID', 'AlleleID(s)', 'dbSNP ID', 'Canonical SPDI', 'Variant type', 'Molecular consequence', 'Germline classification', 'Germline date last evaluated', 'Germline review status', 'Somatic clinical impact', 'Somatic clinical impact date last evaluated', 'Somatic clinical impact review status', 'Oncogenicity classification', 'Oncogenicity date last evaluated', 'Oncogenicity review status', 'Unnamed: 24']
# First few rows:
#                                          Name Gene(s) Protein change  \
# 0  NM_000138.5(FBN1):c.8608C>T (p.Leu2870Phe)    FBN1         L2870F
# 1  NM_000138.5(FBN1):c.8606T>C (p.Leu2869Ser)    FBN1         L2869S
# 2  NM_000138.5(FBN1):c.8603T>G (p.Val2868Gly)    FBN1         V2868G
# 3  NM_000138.5(FBN1):c.8603T>A (p.Val2868Asp)    FBN1         V2868D
# 4  NM_000138.5(FBN1):c.8602G>A (p.Val2868Ile)    FBN1         V2868I
#
#                                         Condition(s)     Accession  \
# 0  Familial thoracic aortic aneurysm and aortic d...  VCV000927302
# 1  Marfan syndrome|Familial thoracic aortic aneur...  VCV001414872
# 2                                       not provided  VCV001175867
# 3  Familial thoracic aortic aneurysm and aortic d...  VCV000519710
# 4  Familial thoracic aortic aneurysm and aortic d...  VCV001171543
#
#    GRCh37Chromosome  GRCh37Location  GRCh38Chromosome  GRCh38Location  \
# 0                15        48703195                15        48410998
# 1                15        48703197                15        48411000
# 2                15        48703200                15        48411003
# 3                15        48703200                15        48411003
# 4                15        48703201                15        48411004
#
#    VariationID  ...                       Germline classification  \
# 0       927302  ...                        Uncertain significance
# 1      1414872  ...                        Uncertain significance
# 2      1175867  ...                        Uncertain significance
# 3       519710  ...                        Uncertain significance
# 4      1171543  ...  Conflicting classifications of pathogenicity
#
#   Germline date last evaluated  \
# 0                  Dec 5, 2023
# 1                 Apr 16, 2024
# 2                  Apr 1, 2021
# 3                 Apr 18, 2016
# 4                 Sep 12, 2024
#
#                               Germline review status Somatic clinical impact  \
# 0                criteria provided, single submitter                     NaN
# 1  criteria provided, multiple submitters, no con...                     NaN
# 2                criteria provided, single submitter                     NaN
# 3                criteria provided, single submitter                     NaN
# 4     criteria provided, conflicting classifications                     NaN
#
#   Somatic clinical impact date last evaluated  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Somatic clinical impact review status Oncogenicity classification  \
# 0                                   NaN                         NaN
# 1                                   NaN                         NaN
# 2                                   NaN                         NaN
# 3                                   NaN                         NaN
# 4                                   NaN                         NaN
#
#   Oncogenicity date last evaluated  Oncogenicity review status  Unnamed: 24
# 0                              NaN                         NaN          NaN
# 1                              NaN                         NaN          NaN
# 2                              NaN                         NaN          NaN
# 3                              NaN                         NaN          NaN
# 4                              NaN                         NaN          NaN
#
# [5 rows x 25 columns]
#
# Conversion complete!
# Input file: clinvar_fbn1.txt
# Output file: clinvar_fbn1.csv
# Rows converted: 4319
#
# === Data Analysis ===
# Total variants: 4319
#
# Germline classification counts:
#   Uncertain significance: 2075
#   Pathogenic: 796
#   Likely pathogenic: 595
#   Conflicting classifications of pathogenicity: 455
#   Pathogenic/Likely pathogenic: 337
#   Likely benign: 38
#   Benign: 14
#   Benign/Likely benign: 9
#
# Variant type counts:
#   single nucleotide variant: 4319
#
# Molecular consequence counts:
#   missense variant: 3912
#   nonsense: 400
#   missense variant|initiator_codon_variant: 7

# %%
df = pd.read_csv('clinvar_fbn1.csv')
df = df.drop(['Somatic clinical impact',
              'Somatic clinical impact date last evaluated',
              'Somatic clinical impact review status',
              'Oncogenicity classification', 
              'Oncogenicity date last evaluated', 
              'Oncogenicity review status', 
              'Unnamed: 24'], axis = 1)
df
# Out:
#                                             Name Gene(s) Protein change  \
# 0     NM_000138.5(FBN1):c.8608C>T (p.Leu2870Phe)    FBN1         L2870F
# 1     NM_000138.5(FBN1):c.8606T>C (p.Leu2869Ser)    FBN1         L2869S
# 2     NM_000138.5(FBN1):c.8603T>G (p.Val2868Gly)    FBN1         V2868G
# 3     NM_000138.5(FBN1):c.8603T>A (p.Val2868Asp)    FBN1         V2868D
# 4     NM_000138.5(FBN1):c.8602G>A (p.Val2868Ile)    FBN1         V2868I
# ...                                          ...     ...            ...
# 4314        NM_000138.5(FBN1):c.2T>C (p.Met1Thr)    FBN1            M1T
# 4315        NM_000138.5(FBN1):c.2T>G (p.Met1Arg)    FBN1            M1R
# 4316        NM_000138.5(FBN1):c.1A>T (p.Met1Leu)    FBN1            M1L
# 4317        NM_000138.5(FBN1):c.1A>C (p.Met1Leu)    FBN1            M1L
# 4318        NM_000138.5(FBN1):c.1A>G (p.Met1Val)    FBN1            M1V
#
#                                            Condition(s)     Accession  \
# 0     Familial thoracic aortic aneurysm and aortic d...  VCV000927302
# 1     Marfan syndrome|Familial thoracic aortic aneur...  VCV001414872
# 2                                          not provided  VCV001175867
# 3     Familial thoracic aortic aneurysm and aortic d...  VCV000519710
# 4     Familial thoracic aortic aneurysm and aortic d...  VCV001171543
# ...                                                 ...           ...
# 4314  Familial thoracic aortic aneurysm and aortic d...  VCV000549124
# 4315  Marfan syndrome|Familial thoracic aortic aneur...  VCV000280307
# 4316  Familial thoracic aortic aneurysm and aortic d...  VCV000577426
# 4317                                    Marfan syndrome  VCV000495569
# 4318  Familial thoracic aortic aneurysm and aortic d...  VCV000180349
#
#       GRCh37Chromosome  GRCh37Location  GRCh38Chromosome  GRCh38Location  \
# 0                   15        48703195                15        48410998
# 1                   15        48703197                15        48411000
# 2                   15        48703200                15        48411003
# 3                   15        48703200                15        48411003
# 4                   15        48703201                15        48411004
# ...                ...             ...               ...             ...
# 4314                15        48936965                15        48644768
# 4315                15        48936965                15        48644768
# 4316                15        48936966                15        48644769
# 4317                15        48936966                15        48644769
# 4318                15        48936966                15        48644769
#
#       VariationID  AlleleID(s)      dbSNP ID             Canonical SPDI  \
# 0          927302       912630  rs2042856175  NC_000015.10:48410997:G:A
# 1         1414872      1474486      rs363848  NC_000015.10:48410999:A:G
# 2         1175867      1166131  rs1555393485  NC_000015.10:48411002:A:C
# 3          519710       510524  rs1555393485  NC_000015.10:48411002:A:T
# 4         1171543      1161120  rs1365239366  NC_000015.10:48411003:C:T
# ...           ...          ...           ...                        ...
# 4314       549124       539956   rs886041536  NC_000015.10:48644767:A:G
# 4315       280307       264741   rs886041536  NC_000015.10:48644767:A:C
# 4316       577426       569532   rs730880097  NC_000015.10:48644768:T:A
# 4317       495569       487865   rs730880097  NC_000015.10:48644768:T:G
# 4318       180349       178703   rs730880097  NC_000015.10:48644768:T:C
#
#                    Variant type                     Molecular consequence  \
# 0     single nucleotide variant                          missense variant
# 1     single nucleotide variant                          missense variant
# 2     single nucleotide variant                          missense variant
# 3     single nucleotide variant                          missense variant
# 4     single nucleotide variant                          missense variant
# ...                         ...                                       ...
# 4314  single nucleotide variant  missense variant|initiator_codon_variant
# 4315  single nucleotide variant  missense variant|initiator_codon_variant
# 4316  single nucleotide variant  missense variant|initiator_codon_variant
# 4317  single nucleotide variant  missense variant|initiator_codon_variant
# 4318  single nucleotide variant  missense variant|initiator_codon_variant
#
#                            Germline classification  \
# 0                           Uncertain significance
# 1                           Uncertain significance
# 2                           Uncertain significance
# 3                           Uncertain significance
# 4     Conflicting classifications of pathogenicity
# ...                                            ...
# 4314                  Pathogenic/Likely pathogenic
# 4315                                    Pathogenic
# 4316                                    Pathogenic
# 4317                                    Pathogenic
# 4318                                    Pathogenic
#
#      Germline date last evaluated  \
# 0                     Dec 5, 2023
# 1                    Apr 16, 2024
# 2                     Apr 1, 2021
# 3                    Apr 18, 2016
# 4                    Sep 12, 2024
# ...                           ...
# 4314                 Aug 15, 2025
# 4315                 Sep 28, 2024
# 4316                  Sep 5, 2025
# 4317                 Sep 26, 2023
# 4318                 Nov 28, 2023
#
#                                  Germline review status
# 0                   criteria provided, single submitter
# 1     criteria provided, multiple submitters, no con...
# 2                   criteria provided, single submitter
# 3                   criteria provided, single submitter
# 4        criteria provided, conflicting classifications
# ...                                                 ...
# 4314  criteria provided, multiple submitters, no con...
# 4315  criteria provided, multiple submitters, no con...
# 4316  criteria provided, multiple submitters, no con...
# 4317                           reviewed by expert panel
# 4318  criteria provided, multiple submitters, no con...
#
# [4319 rows x 18 columns]

# %%
df[['trash', 'mutation']] = df['Name'].str.split(':', expand=True)

# %%
df[['mutation_1', 'trashh']] = df['mutation'].str.split('(', expand=True)

# %%
df = df.drop(['trash', 'trashh', 'mutation'], axis = 1)

# %%
df.to_csv('fbn_snp.csv')
